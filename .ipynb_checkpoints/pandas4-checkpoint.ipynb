# %%
import pandas as pd
laptop = pd.read_csv("./laptop_pricing_sample.csv")
laptop.head()
# Out:
#   Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_cm  CPU_frequency  \
# 0         Dell         1    3   1         7            39.6            3.5
# 1           HP         3    2   1         5            35.6            2.8
# 2       Lenovo         4    1   2         3            33.0            2.5
# 3         Asus         2    3   1         5            29.5            3.0
# 4        Apple         4    2   1         7            34.0            3.2
#
#    RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0      16             512        2.5   1500
# 1       8             256        2.0    900
# 2       4             128        1.8    600
# 3       8             512        1.5    750
# 4      16            1024        1.3   2000

# %%
filtered = laptop[(laptop["Price"] > 500) & (laptop["CPU_core"] > 3)]
print(filtered)
# Out:
#   Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_cm  CPU_frequency  \
# 0         Dell         1    3   1         7            39.6            3.5
# 1           HP         3    2   1         5            35.6            2.8
# 3         Asus         2    3   1         5            29.5            3.0
# 4        Apple         4    2   1         7            34.0            3.2
# 5          MSI         1    3   1         7            40.0            3.6
# 7         Dell         5    2   1         5            38.0            3.1
# 8           HP         3    1   2         5            32.0            2.7
#
#    RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0      16             512        2.5   1500
# 1       8             256        2.0    900
# 3       8             512        1.5    750
# 4      16            1024        1.3   2000
# 5      32            1024        2.8   2200
# 7      16             512        2.6   1600
# 8       8             128        2.0    850
