# %%
import pandas as pd
import numpy as np
bios = pd.read_csv("./athlete_events.csv")
bios[(bios['ID']>5) & (bios['City'] == 'Calgary')]
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 633        367                Masashi Abe   M  22.0   175.0    64.0
# 634        367                Masashi Abe   M  22.0   175.0    64.0
# 734        422  Julianne "Anne" Abernathy   F  34.0   165.0    75.0
# 815        466   Piroska Abos Gvorgyzakab   F  25.0     NaN     NaN
# 816        466   Piroska Abos Gvorgyzakab   F  25.0     NaN     NaN
# ...        ...                        ...  ..   ...     ...     ...
# 270876  135465          Pirmin Zurbriggen   M  25.0   183.0    83.0
# 270877  135465          Pirmin Zurbriggen   M  25.0   183.0    83.0
# 270878  135465          Pirmin Zurbriggen   M  25.0   183.0    83.0
# 270879  135465          Pirmin Zurbriggen   M  25.0   183.0    83.0
# 270880  135465          Pirmin Zurbriggen   M  25.0   183.0    83.0
#
#                                 Team  NOC        Games  Year  Season     City  \
# ...

# %%
bios[(bios['Sex'] == 'M') & (bios['City'] == 'Calgary')]
# Out:
#             ID                 Name Sex   Age  Height  Weight         Team  \
# 633        367          Masashi Abe   M  22.0   175.0    64.0        Japan
# 634        367          Masashi Abe   M  22.0   175.0    64.0        Japan
# 922        522  Knut Leo Abrahamsen   M  25.0     NaN     NaN       Norway
# 1132       634          Paul Accola   M  20.0   176.0    82.0  Switzerland
# 1133       634          Paul Accola   M  20.0   176.0    82.0  Switzerland
# ...        ...                  ...  ..   ...     ...     ...          ...
# 270876  135465    Pirmin Zurbriggen   M  25.0   183.0    83.0  Switzerland
# 270877  135465    Pirmin Zurbriggen   M  25.0   183.0    83.0  Switzerland
# 270878  135465    Pirmin Zurbriggen   M  25.0   183.0    83.0  Switzerland
# 270879  135465    Pirmin Zurbriggen   M  25.0   183.0    83.0  Switzerland
# 270880  135465    Pirmin Zurbriggen   M  25.0   183.0    83.0  Switzerland
#
#         NOC        Games  Year  Season     City            Sport  \
# ...

# %%
bios[bios['Name'].str.contains("Pirmin")]
# Out:
#             ID               Name Sex   Age  Height  Weight         Team  NOC  \
# 270873  135465  Pirmin Zurbriggen   M  21.0   183.0    83.0  Switzerland  SUI
# 270874  135465  Pirmin Zurbriggen   M  21.0   183.0    83.0  Switzerland  SUI
# 270875  135465  Pirmin Zurbriggen   M  21.0   183.0    83.0  Switzerland  SUI
# 270876  135465  Pirmin Zurbriggen   M  25.0   183.0    83.0  Switzerland  SUI
# 270877  135465  Pirmin Zurbriggen   M  25.0   183.0    83.0  Switzerland  SUI
# 270878  135465  Pirmin Zurbriggen   M  25.0   183.0    83.0  Switzerland  SUI
# 270879  135465  Pirmin Zurbriggen   M  25.0   183.0    83.0  Switzerland  SUI
# 270880  135465  Pirmin Zurbriggen   M  25.0   183.0    83.0  Switzerland  SUI
#
#               Games  Year  Season      City          Sport  \
# 270873  1984 Winter  1984  Winter  Sarajevo  Alpine Skiing
# 270874  1984 Winter  1984  Winter  Sarajevo  Alpine Skiing
# 270875  1984 Winter  1984  Winter  Sarajevo  Alpine Skiing
# ...

# %%
bios.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
bios[bios['Name'].str.contains("Jacoba")]
# Out:
#             ID                                               Name Sex   Age  \
# 4            5                           Christine Jacoba Aaftink   F  21.0
# 5            5                           Christine Jacoba Aaftink   F  21.0
# 6            5                           Christine Jacoba Aaftink   F  25.0
# 7            5                           Christine Jacoba Aaftink   F  25.0
# 8            5                           Christine Jacoba Aaftink   F  27.0
# 9            5                           Christine Jacoba Aaftink   F  27.0
# 1782       986          Adriana Johanna Jacoba Admiraal-Meijerink   F  30.0
# 1783       986          Adriana Johanna Jacoba Admiraal-Meijerink   F  34.0
# 50415    25942                        Johanna Jacoba "Jo" de Boer   F  23.0
# 50416    25942                        Johanna Jacoba "Jo" de Boer   F  27.0
# 50417    25942                        Johanna Jacoba "Jo" de Boer   F  31.0
# ...
